# %% [markdown]
# # Diffusion Policy

# %%
# !git clone https://github.com/cadenpage/diffusion-policy.git
# %cd diffusion-policy
# !python3.12 -m pip install -r requirements.txt
# Out:
# Cloning into 'diffusion-policy'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.
# Resolving deltas: 100% (1/1), done.
# /Users/cadenpage/dev/diffusion-policy/scripts/diffusion-policy
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from huggingface_hub import login
login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/dev/diffusion-policy/.venv/lib/python3.12/site-packages/huggingface_hub/_login.py:315, in notebook_login(skip_if_logged_in)
#     314 try:
# --> 315     import ipywidgets.widgets as widgets  # type: ignore
#     316     from IPython.display import display  # type: ignore
#
# ModuleNotFoundError: No module named 'ipywidgets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 from huggingface_hub import login
# ----> 2 login()
#
# File ~/dev/diffusion-policy/.venv/lib/python3.12/site-packages/huggingface_hub/_login.py:115, in login(token, add_to_git_credential, skip_if_logged_in)
#     113     _login(token, add_to_git_credential=add_to_git_credential)
#     114 elif is_notebook():
# --> 115     notebook_login(skip_if_logged_in=skip_if_logged_in)
#     116 else:
#     117     interpreter_login(skip_if_logged_in=skip_if_logged_in)
#
# File ~/dev/diffusion-policy/.venv/lib/python3.12/site-packages/huggingface_hub/_login.py:318, in notebook_login(skip_if_logged_in)
#     316     from IPython.display import display  # type: ignore
#     317 except ImportError:
# --> 318     raise ImportError(
#     319         "The `notebook_login` function can only be used in a notebook (Jupyter or"
#     320         " Colab) and you need the `ipywidgets` module: `pip install ipywidgets`."
#     321     )
#     322 if skip_if_logged_in and get_token() is not None:
#     323     logger.info("User is already logged in. Use `hf auth login --force` to force re-login.")
#
# ImportError: The `notebook_login` function can only be used in a notebook (Jupyter or Colab) and you need the `ipywidgets` module: `pip install ipywidgets`.

# %%
# !./.venv/bin/lerobot-train \
  --dataset.repo_id=caden-ut/rotom_task_teleop \
  --policy.type=diffusion \
  --policy.device=cuda \
  --policy.use_amp=false \
  --policy.n_obs_steps=2 \
  --policy.repo_id=caden-ut/rotom_task_teleop_diffusion \
  --batch_size=8 \
  --num_workers=2 \
  --steps=5000 \
  --save_freq=1000 \
  --log_freq=50 \
  --wandb.enable=false \
  --output_dir=/content/outputs/train/rotom_task_teleop_diffusion \
  --job_name=rotom_task_teleop_diffusion

# %%
DiffusionPolicy.from_pretrained("caden-ut/rotom_task_teleop_diffusion")
